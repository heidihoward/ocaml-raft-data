# %%
import matplotlib.pyplot as plt
import numpy as np
import csv

# %%
graph_a = ['12-24','25-50','50-100','100-200','150-300']
graph_b = ['150-151','150-155','150-175','150-200','150-300']

# %%
#read data in
data_dict = {}
for graph in [graph_a,graph_b]:
    for line in graph:
        file = open('raw/'+line+'results.log')
        file_reader = csv.reader(file,delimiter='\n')
        data_dict[line] = []
        for point in file_reader:
            data_dict[line] += point

# %%
# convert to ms floats
flt_dict = {}
for line in graph_a + graph_b:
    flt_dict[line] = []
    for point in data_dict[line]:
        flt_dict[line].append(float(point)/100.0)
    flt_dict[line].sort()

# %%
y_axis = []
size = len(flt_dict[graph_a[0]])
for y in range (1,size+1):
    y_axis.append(y*100.0/size)

# %%
fig = plt.figure()

axes = fig.add_axes([0.1, 0.1, 0.8, 0.8]) # left, bottom, width, height (range 0 to 1)

for line in graph_a:
    if (len(flt_dict[line]) != len(y_axis)):
        print (line)
    axes.plot(flt_dict[line],y_axis)
    
# labels
axes.set_xlabel('Time to elect leader (ms)')
axes.set_ylabel('Cummulative percent')
axes.set_title('Time taken to elect leader')

# ticks & axes

y_marked = [0,20,40,60,80,100]
axes.set_yticks(y_marked)
axes.set_yticklabels(['0%','20%','40%','60%','80%','100%'])

axes.legend(graph_a)
fig.savefig("graphs/graph_a.png")

# %%
fig = plt.figure()

axes = fig.add_axes([0.1, 0.1, 0.8, 0.8]) # left, bottom, width, height (range 0 to 1)

for line in graph_b:
    if (len(flt_dict[line]) != len(y_axis)):
        print (line)
        print (len(flt_dict[line]))
        print (len(y_axis))
    axes.plot(flt_dict[line],y_axis)

# labels
axes.set_xlabel('Time to elect leader (ms)')
axes.set_ylabel('Cummulative percent')
axes.set_title('Time taken to elect leader')

# ticks & axes
axes.set_xscale("log")
x_marked = [100, 150, 300, 500, 1000, 3000, 5000, 10000]
axes.set_xticks(x_marked)
axes.set_xticklabels(x_marked)
axes.set_xlim([75,10000])

y_marked = [0,20,40,60,80,100]
axes.set_yticks(y_marked)
axes.set_yticklabels(['0%','20%','40%','60%','80%','100%'])

axes.legend(graph_b)
fig.savefig("graphs/graph_b.png")
